# %%
import numpy as np
import pandas as pd
import os

# %%
root_path = "/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/"
path_nav = os.path.join(root_path, "navigation.csv")
path_obj = os.path.join(root_path, "objects.csv")
df_nav = pd.read_csv(path_nav)
df_obj = pd.read_csv(path_obj)

# %%
df_nav.head()
# Out:
#    Unnamed: 0     ag-action  ag-pos-x  ag-pos-y  ag-pos-z  ag-rot-x  ag-rot-y  \
# 0           0  rotate_right      5.85       0.9      2.55      -0.0     210.0
# 1           1  rotate_right      5.85       0.9      2.55      -0.0     210.0
# 2           2  rotate_right      5.85       0.9      2.55      -0.0     210.0
# 3           3  rotate_right      5.85       0.9      2.55      -0.0     210.0
# 4           4  rotate_right      5.85       0.9      2.55      -0.0     210.0
#
#    ag-rot-z                             obj-id  obj-distance  \
# 0       0.0                     ObjaPepper|2|3        1.2836
# 1       0.0                           Cup|2|10        1.0195
# 2       0.0                    ObjaCounter|2|1        1.1766
# 3       0.0  wall|exterior|3.22|1.61|6.44|1.61        1.8052
# 4       0.0                            Cup|2|9        0.5975
#
#                                                 path
# 0  /home/andreina/Documents/Programs/Dataset/Gene...
# 1  /home/andreina/Documents/Programs/Dataset/Gene...
# 2  /home/andreina/Documents/Programs/Dataset/Gene...
# 3  /home/andreina/Documents/Programs/Dataset/Gene...
# 4  /home/andreina/Documents/Programs/Dataset/Gene...

# %%
def get_records_navigation(csv_path):
    df = pd.read_csv(csv_path)
    dict_navigation = {}
    for _, row in df.iterrows():
        action = row.get("ag-action")
        ag_pos_x = row.get("ag-pos-x")
        ag_pos_y = row.get("ag-pos-y")
        ag_pos_z = row.get("ag-pos-z")
        ag_rot_x = row.get("ag-rot-x")
        ag_rot_y = row.get("ag-rot-y")
        ag_rot_z = row.get("ag-rot-z")
        obj = row.get("obj-id")
        # obj_pos_x = row.get("obj-pos-x")
        # obj_pos_y = row.get("obj-pos-y")
        # obj_pos_z = row.get("obj-pos-z")
        dist = row["obj-distance"]
        # cmin = row.get("cmin")
        # rmin = row.get("rmin")
        # cmax = row.get("cmax")
        # rmax = row.get("rmax")
        path = row.get("path")
        key = (action, (ag_pos_x, ag_pos_y, ag_pos_z), (ag_rot_x, ag_rot_y, ag_rot_z), path)
        if key not in dict_navigation:
            dict_navigation[key] = []
        dict_navigation[key].append({
            "Object": obj, 
            # "Position": (obj_pos_x, obj_pos_y, obj_pos_z), 
            "Distance": dist,
            # "BBox": (cmin, rmin, cmax, rmax)
        })
    return dict_navigation

# %%
dict_nav = get_records_navigation(path_nav)

# %%
dict_nav
# Out:
# {('rotate_right',
#   (5.85, 0.9, 2.55),
#   (-0.0, 210.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_0.png'): [{'Object': 'ObjaPepper|2|3',
#    'Distance': 1.2836},
#   {'Object': 'Cup|2|10', 'Distance': 1.0195},
#   {'Object': 'ObjaCounter|2|1', 'Distance': 1.1766},
#   {'Object': 'wall|exterior|3.22|1.61|6.44|1.61', 'Distance': 1.8052},
#   {'Object': 'Cup|2|9', 'Distance': 0.5975},
#   {'Object': 'Knife|2|7', 'Distance': 1.2934},
#   {'Object': 'Plate|2|12', 'Distance': 1.0175},
#   {'Object': 'ObjaPouch|2|1', 'Distance': 0.7196},
#   {'Object': 'HousePlant|2|18', 'Distance': 0.8963}],
#  ('rotate_right',
#   (5.85, 0.9, 2.55),
#   (-0.0, 240.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_1.png'): [{'Object': 'ObjaPepper|2|3',
#    'Distance': 1.2836},
#   {'Object': 'Cup|2|10', 'Distance': 1.0195},
#   {'Object': 'ObjaCounter|2|1', 'Distance': 1.1766},
#   {'Object': 'wall|exterior|3.22|1.61|6.44|1.61', 'Distance': 1.8052},
#   {'Object': 'Knife|2|7', 'Distance': 1.2934},
#   {'Object': 'Plate|2|12', 'Distance': 1.0175},
#   {'Object': 'ObjaPouch|2|1', 'Distance': 0.7196},
#   {'Object': 'HousePlant|2|18', 'Distance': 0.8963}],
#  ('rotate_right',
#   (5.85, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_2.png'): [{'Object': 'ObjaPepper|2|3',
#    'Distance': 1.2836},
#   {'Object': 'wall|exterior|4.83|3.22|6.44|3.22', 'Distance': 1.3539},
#   {'Object': 'ObjaCounter|2|1', 'Distance': 1.1766},
#   {'Object': 'wall|exterior|3.22|1.61|6.44|1.61', 'Distance': 1.8052},
#   {'Object': 'Knife|2|7', 'Distance': 1.2934},
#   {'Object': 'Plate|2|12', 'Distance': 1.0175},
#   {'Object': 'HousePlant|2|18', 'Distance': 0.8963}],
#  ('move_ahead',
#   (5.65, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_3.png'): [{'Object': 'ObjaPepper|2|3',
#    'Distance': 1.1332},
#   {'Object': 'ObjaCounter|2|1', 'Distance': 1.1335},
#   {'Object': 'wall|exterior|3.22|1.61|6.44|1.61', 'Distance': 1.7004},
#   {'Object': 'window|2|0', 'Distance': 1.4761},
#   {'Object': 'Knife|2|7', 'Distance': 1.1353},
#   {'Object': 'Plate|2|12', 'Distance': 0.8711}],
#  ('move_ahead',
#   (5.45, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_4.png'): [{'Object': 'ObjaCounter|2|1',
#    'Distance': 1.1248},
#   {'Object': 'wall|exterior|3.22|1.61|6.44|1.61', 'Distance': 1.6136},
#   {'Object': 'Knife|2|7', 'Distance': 0.9923},
#   {'Object': 'Plate|2|12', 'Distance': 0.7498},
#   {'Object': 'window|2|0', 'Distance': 1.3339}],
#  ('move_ahead',
#   (5.25, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_5.png'): [{'Object': 'ObjaCounter|2|1',
#    'Distance': 1.1513},
#   {'Object': 'wall|exterior|3.22|1.61|6.44|1.61', 'Distance': 1.5479},
#   {'Object': 'window|2|0', 'Distance': 1.2081},
#   {'Object': 'Knife|2|7', 'Distance': 0.8721}],
#  ('move_ahead',
#   (5.05, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_6.png'): [{'Object': 'wall|exterior|3.22|1.61|6.44|1.61',
#    'Distance': 1.5061}],
#  ('move_ahead',
#   (4.85, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_7.png'): [{'Object': 'ObjaRefrigerator|2|3',
#    'Distance': 2.1641},
#   {'Object': 'wall|exterior|3.22|1.61|6.44|1.61', 'Distance': 1.4903},
#   {'Object': 'window|2|0', 'Distance': 1.0296}],
#  ('move_ahead',
#   (4.65, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_8.png'): [{'Object': 'wall|exterior|3.22|1.61|6.44|1.61',
#    'Distance': 1.5011},
#   {'Object': 'ObjaRefrigerator|2|3', 'Distance': 2.0591},
#   {'Object': 'window|2|0', 'Distance': 0.9901}],
#  ('move_ahead',
#   (4.45, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_9.png'): [{'Object': 'wall|exterior|3.22|3.22|3.22|4.83',
#    'Distance': 2.2419},
#   {'Object': 'wall|exterior|3.22|1.61|6.44|1.61', 'Distance': 1.5381},
#   {'Object': 'ObjaRefrigerator|2|3', 'Distance': 1.9689},
#   {'Object': 'window|2|0', 'Distance': 0.9902}],
#  ('move_ahead',
#   (4.25, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_10.png'): [{'Object': 'wall|exterior|3.22|3.22|3.22|4.83',
#    'Distance': 2.1388},
#   {'Object': 'wall|2|0.00|3.22|3.22|3.22', 'Distance': 2.9587},
#   {'Object': 'wall|exterior|3.22|1.61|6.44|1.61', 'Distance': 1.5994},
#   {'Object': 'wall|2|3.22|0.00|3.22|1.61', 'Distance': 2.3325}],
#  ('move_ahead',
#   (4.05, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_11.png'): [{'Object': 'wall|exterior|3.22|3.22|3.22|4.83',
#    'Distance': 2.0501},
#   {'Object': 'wall|2|0.00|3.22|3.22|3.22', 'Distance': 2.7818},
#   {'Object': 'wall|2|3.22|0.00|3.22|1.61', 'Distance': 2.2515}],
#  ('move_ahead',
#   (3.85, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_12.png'): [{'Object': 'wall|2|0.00|3.22|3.22|3.22',
#    'Distance': 2.6082}],
#  ('move_ahead',
#   (3.65, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_13.png'): [{'Object': 'wall|2|0.00|3.22|3.22|3.22',
#    'Distance': 2.4386}],
#  ('move_ahead',
#   (3.45, 0.9, 2.55),
#   (-0.0, 270.0, 0.0),
#   '/home/andreina/Documents/Programs/Dataset/Generated/navigation/11_28_2025_07_09_06_636865/images/img_14.png'): [{'Object': 'wall|2|0.00|3.22|3.22|3.22',
#    'Distance': 2.274},
#   {'Object': 'door|1|2', 'Distance': 3.5245}]}

# %%
df_obj.head()
# Out:
#    Unnamed: 0          obj-type                             obj-id  obj-pos-x  \
# 0           0  ObjaRefrigerator               ObjaRefrigerator|2|3       3.64
# 1           1              Wall  wall|exterior|4.83|3.22|6.44|3.22       5.64
# 2           2             Plate                         Plate|2|12       5.06
# 3           3               Cup                            Cup|2|9       5.94
# 4           4               Cup                           Cup|2|10       5.28
#
#    obj-pos-y  obj-pos-z  obj-rot-x  obj-rot-y  obj-rot-z  \
# 0       0.01       4.11       0.00     180.00       0.00
# 1       2.06       3.22      -0.00     180.00       0.00
# 2       0.94       1.91       0.80     359.97       1.62
# 3       0.96       1.96     356.05     359.86       0.40
# 4       0.94       1.71     355.85     359.76       0.58
#
#         receptacleObjectIds  objOrBBox-x   objOrBBox-y  objOrBBox-z
# 0  ('Egg|2|15', 'Egg|2|16')     3.246004  1.788139e-07     3.406242
# 1                        ()     0.000000  0.000000e+00     0.000000
# 2                        ()     4.933668  9.319944e-01     1.787072
# 3                        ()     5.886028  9.556358e-01     1.894020
# 4                        ()     5.232354  9.340421e-01     1.648068

# %%
def calculate_focal_length(val, fov):
    f = val / (2 * np.tan(np.deg2rad(fov/2)))
    return f

def get_other_fov(val1, val2, fov):
    fov_other = 2 * np.arctan((val1 / val2) * np.tan(np.deg2rad(fov / 2)))
    return np.degrees(fov_other)

def get_focal_length(w, h, fov_v):
    fy = calculate_focal_length(h, fov_v)
    fov_h = get_other_fov(w, h, fov_v)
    # print("fov_h", fov_h)
    fx = calculate_focal_length(w, fov_h)
    # print(f"Focal length -> fx: {fx}, fy: {fy}.")
    # print(f"Fov-> h: {fov_h}, v: {fov_v}")
    return fx, fy, fov_h

def get_center_point(bbox):
    xc = np.mean([bbox[0], bbox[2]])
    yc = np.mean([bbox[1], bbox[3]])
    return xc, yc

def calculate_angle(coord1, coord2):
    angle = np.arctan2(coord1, coord2)
    return np.degrees(angle)

def world_to_local(agent_pos, agent_rot_deg, object_pos):
    # agent_rot_deg = (pitch_x, yaw_y, roll_z) in degrees
    pitch, yaw, roll = np.deg2rad(agent_rot_deg)
    Rx = np.array([[1,0,0],
                   [0,np.cos(pitch),-np.sin(pitch)],
                   [0,np.sin(pitch), np.cos(pitch)]])
    Ry = np.array([[ np.cos(yaw),0,np.sin(yaw)],
                   [0,1,0],
                   [-np.sin(yaw),0,np.cos(yaw)]])
    Rz = np.array([[np.cos(roll),-np.sin(roll),0],
                   [np.sin(roll), np.cos(roll),0],
                   [0,0,1]])
    R_cw = Ry @ Rx @ Rz         # camera->world
    R_wc = R_cw.T               # world->camera
    Pw = np.asarray(object_pos).reshape(3,1)
    C  = np.asarray(agent_pos).reshape(3,1)
    Pl = (R_wc @ (Pw - C)).flatten()  # local (Xl,Yl,Zl)
    # return R_wc, Pw, C, Pl
    return Pl  # (x_l, y_l, z_l)

def projection_with_local_vector(local_xyz, c_point, foc_l):
    xl, yl, zl = local_xyz
    if zl <= 0:
        print(f"Z none: {zl}")
        # return None  # behind camera
        # zl = 0.001
        zl = np.absolute(zl)
    # fx, fy, cx, cy = intrinsics_from_fov(W, H, fov_h, fov_v)
    u = foc_l[0] * (xl / zl) + c_point[0]
    v = foc_l[1] * (yl / zl) + c_point[1]
    # if 0 <= u < W and 0 <= v < H:
    #     return (float(u), float(v))
    return float(u), float(v)

def transform_3d_to_2d(ag_pos, ag_rot, obj_pos, c_point, foc_l):
    x_l, y_l, z_l = world_to_local(ag_pos, ag_rot, obj_pos)
    alpha = calculate_angle(x_l, z_l)
    betha = calculate_angle(y_l, z_l)
    # u_b, v_b = get_center_point(bbox)
    # u_a, v_a = projection_with_angles(foc_l, alpha, betha, c_point)
    u_l, v_l = projection_with_local_vector((x_l, y_l, z_l), c_point, foc_l)
    # return (u_b, v_b), (u_a, v_a), (u_l, v_l), alpha, betha
    return (x_l, y_l, z_l), (u_l, v_l), alpha, betha

def get_x_direction(alpha, fov_h, epsilon=1/3):
    t_alpha = epsilon * (fov_h / 2)
    x_dir = "front"
    if alpha >t_alpha:
        x_dir = "right"
    elif alpha < t_alpha * -1:
        x_dir = "left"
    return x_dir

def get_y_direction(betha, fov_v, epsilon=1/3):
    t_betha = epsilon * (fov_v / 2)
    y_dir = ""
    if betha > t_betha:
        y_dir = "above"
    elif betha < (t_betha * -1):
        y_dir = "below"
    return y_dir

def get_z_direction(distance):
    return distance

def get_direction(alpha, betha, distance, fov_h, fov_v, epsilon=1/3):
    x_dir = get_x_direction(alpha, fov_h, epsilon) #rirght, left
    y_dir = get_y_direction(betha, fov_v, epsilon) # above, below
    z_dir = get_z_direction(distance) # front, behind
    return x_dir, y_dir, z_dir

# %%
df_obj.head()
# Out:
#    Unnamed: 0          obj-type                             obj-id  obj-pos-x  \
# 0           0  ObjaRefrigerator               ObjaRefrigerator|2|3       3.64
# 1           1              Wall  wall|exterior|4.83|3.22|6.44|3.22       5.64
# 2           2             Plate                         Plate|2|12       5.06
# 3           3               Cup                            Cup|2|9       5.94
# 4           4               Cup                           Cup|2|10       5.28
#
#    obj-pos-y  obj-pos-z  obj-rot-x  obj-rot-y  obj-rot-z  \
# 0       0.01       4.11       0.00     180.00       0.00
# 1       2.06       3.22      -0.00     180.00       0.00
# 2       0.94       1.91       0.80     359.97       1.62
# 3       0.96       1.96     356.05     359.86       0.40
# 4       0.94       1.71     355.85     359.76       0.58
#
#         receptacleObjectIds  objOrBBox-x   objOrBBox-y  objOrBBox-z
# 0  ('Egg|2|15', 'Egg|2|16')     3.246004  1.788139e-07     3.406242
# 1                        ()     0.000000  0.000000e+00     0.000000
# 2                        ()     4.933668  9.319944e-01     1.787072
# 3                        ()     5.886028  9.556358e-01     1.894020
# 4                        ()     5.232354  9.340421e-01     1.648068

# %%
r = df_obj[df_obj["obj-id"] == "ObjaRefrigerator|2|3"].iloc[0]
r
# Out:
# Unnamed: 0                                    0
# obj-type                       ObjaRefrigerator
# obj-id                     ObjaRefrigerator|2|3
# obj-pos-x                                  3.64
# obj-pos-y                                  0.01
# obj-pos-z                                  4.11
# obj-rot-x                                   0.0
# obj-rot-y                                 180.0
# obj-rot-z                                   0.0
# receptacleObjectIds    ('Egg|2|15', 'Egg|2|16')
# objOrBBox-x                            3.246004
# objOrBBox-y                                 0.0
# objOrBBox-z                            3.406242
# Name: 0, dtype: object

# %%
import ast

# %%
df_obj['obj-id'].isin(['ObjaRefrigerator|2|3']).any()
# Out:
# True

# %%
def transform_text2list(text):
    # print(text, type(text))
    t = ast.literal_eval(text)
    l = list(t)
    return l

# %%
import cv2
import seaborn as sns

# %%
def draw_on_frame(frame_bgr, uvs, palette):
    if uvs is None:
        return frame_bgr
    # u, v = int(round(uv[0])), int(round(uv[1]))
    out = frame_bgr.copy()
    # cv2.circle(out, (0, 0), 6, (255, 0, 0), -1)
    # cv2.circle(out, p_point, 6, (0, 0, 255), -1)
    for i, (u, v) in enumerate(uvs):
        u, v = int(round(u)), int(round(v))
        (r, g, b) = palette[i%10]
        (r, g, b) = (int(255*r), int(255*g), int(255*b))
        cv2.circle(out, (u, v), 6, (r, g, b), -1)
        cv2.putText(out, str(i), (u, v), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    return out

# %%
'''
json format


agent_frame: "egocentric"
sequence: [
  {
    path_image:
    step:
    action: 
    objects: [
        obj1: {
            pos
            dist
        },
        obj2: {
            ...
        }
    ]
  },
  {
    path_image:
    ...
  }, 
  ...
]
'''
# sequence = []
data_json = {
    "agent_frame": "egocentric",
    "sequence": []
}

# %%
"manta".startswith("man")
# Out:
# True

# %%
n = "nuevo"
j = 6
r = f"text {n} with {j}"
r
# Out:
# 'text nuevo with 6'

# %%
import re

def camel_to_words(text):
    new_word = re.sub(r'(?<!^)(?=[A-Z])', ' ', text)
    words = new_word.split(" ")
    new_word = words[1] if len(words) > 1 else words[0]
    return new_word.lower()

# %%
def get_horizontal_phrase(text):
    new_text = "in front of" if text == "front" else f"to the {text} of"
    return new_text

def get_vertical_phrase(text):
    new_text = f" and {text} eye level" if text else text
    return new_text

def get_dist_phrase(text):
    new_text = text
    if text == "medium":
        new_text = "at a medium distance"
    elif text == "far":
        new_text = "far away"
    return new_text

def get_distance_text(number):
    text = ""
    if number < 1.5:
        text = "near"
    elif number > 1.5 and number < 2.5:
        text = "medium"
    else:
        text = "far"
    return text

# %%
def get_spatial_descriptions(object_dict):
    name = object_dict["object_name"]
    dir = object_dict["egocentric_label"]
    phr_dir_x = get_horizontal_phrase(dir["horiz"])
    phr_dir_y = get_vertical_phrase(dir["vert"])
    phr_dir_z = get_dist_phrase(dir["dist"])
    if phr_dir_y:
        text = f"From the agent's viewpoint, the {name} is {phr_dir_x} the agent, {phr_dir_z}{phr_dir_y}"
    else:
        text = f"From the agent's viewpoint, the {name} is {phr_dir_x} the agent and {phr_dir_z}"
    return text

# %%
# create a json file for training a LLM
def get_spatial_relations(dict_navigation, episode_id, df_obj, w, h, fov_v, epsilon=1/3,):
    spatial_data = {
        "episode": episode_id,
        "agent_frame": "egocentric",
        "sequence": []
    }
    spatial_annotation = {
        "episode": episode_id,
        "sequence": []
    }
    trajectories = {
        "episode": episode_id
    }
    fx, fy, fov_h = get_focal_length(w, h, fov_v)
    c_point = (w // 2, h // 2)
    deg = 30
    for i, (d_agent, d_objects) in enumerate(dict_navigation.items()):
        action, ag_pos, ag_rot, path = d_agent
        ag_pos = np.array(ag_pos)
        ag_rot = np.array(ag_rot)
        step_dict = {
            "step": i,
            "action": "initialize" if i == 0 else action,
            "degrees": deg if i > 0 else 0,
            "objects": {}
        }
        description_dict = {
            "step": i,
            "objects": {}
        }
        for d_object in d_objects:
            data_json_object = {}
            obj_id = d_object["Object"]
            if obj_id not in trajectories:
                trajectories[obj_id] = []
            obj_dist = d_object["Distance"]
            data_object = df_obj[df_obj['obj-id'] == obj_id].iloc[0]
            obj_pos = tuple(data_object[['obj-pos-x', 'obj-pos-y', 'obj-pos-z']])
            recep_objs = transform_text2list(data_object['receptacleObjectIds'])
            filtered_recep_objs = []
            if recep_objs:
                for recep_obj in recep_objs:
                    if df_obj['obj-id'].isin([recep_obj]).any():
                        filtered_recep_objs.append(recep_obj)
            obj_pos = np.array(obj_pos)
            w_to_l, p_l, alpha, betha = transform_3d_to_2d(ag_pos, ag_rot, obj_pos, c_point, (fx, fy)) 
            dir_x, dir_y, dir_z = get_direction(alpha, betha, obj_dist, fov_h, fov_v, epsilon)
            if obj_id.startswith("window") or obj_id.startswith("wall"):
                dir_y = ""
            data_json_object["object_name"] = camel_to_words(data_object['obj-type'])
            data_json_object["egocentric_label"] = {
                "horiz": dir_x, 
                "vert": dir_y,
                "dist": get_distance_text(dir_z)
            }
            data_json_object["relations"] = {
                "contains": filtered_recep_objs
            }
            step_dict["objects"][obj_id] = data_json_object
            description_dict["objects"][obj_id] = get_spatial_descriptions(data_json_object)
            trajectories[obj_id].append({"step": i, "horiz": dir_x, "vert": dir_y, "dist": get_distance_text(dir_z)})
        spatial_data["sequence"].append(step_dict)
        spatial_annotation["sequence"].append(description_dict)
    return spatial_data, spatial_annotation, trajectories

# %%
w, h = 396, 224
# p_point = (w//2, h//2)
fov_v = 59
sp_data, spat_ann, traj = get_spatial_relations(dict_nav, "ep_1", df_obj, w, h, fov_v)
# Out:
# Z none: -0.0499999999999997
# Z none: -0.24999999999999986
# Z none: -0.17999999999999955
# Z none: -0.3799999999999997
# Z none: -0.09999999999999948
# Z none: -0.5799999999999998

# %%
sp_data
# Out:
# {'episode': 'ep_1',
#  'agent_frame': 'egocentric',
#  'sequence': [{'step': 0,
#    'action': 'initialize',
#    'degrees': 0,
#    'objects': {'ObjaPepper|2|3': {'object_name': 'pepper',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'Cup|2|10': {'object_name': 'cup',
#      'egocentric_label': {'horiz': 'front', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'ObjaCounter|2|1': {'object_name': 'counter',
#      'egocentric_label': {'horiz': 'front', 'vert': 'below', 'dist': 'near'},
#      'relations': {'contains': ['ObjaPouch|2|1',
#        'Cup|2|9',
#        'ObjaPepper|2|3',
#        'Cup|2|10',
#        'HousePlant|2|18',
#        'Plate|2|12',
#        'Knife|2|7']}},
#     'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'Cup|2|9': {'object_name': 'cup',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'Knife|2|7': {'object_name': 'knife',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'Plate|2|12': {'object_name': 'plate',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'ObjaPouch|2|1': {'object_name': 'pouch',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'HousePlant|2|18': {'object_name': 'plant',
#      'egocentric_label': {'horiz': 'front', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}}}},
#   {'step': 1,
#    'action': 'rotate_right',
#    'degrees': 30,
#    'objects': {'ObjaPepper|2|3': {'object_name': 'pepper',
#      'egocentric_label': {'horiz': 'front', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'Cup|2|10': {'object_name': 'cup',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'ObjaCounter|2|1': {'object_name': 'counter',
#      'egocentric_label': {'horiz': 'left', 'vert': 'below', 'dist': 'near'},
#      'relations': {'contains': ['ObjaPouch|2|1',
#        'Cup|2|9',
#        'ObjaPepper|2|3',
#        'Cup|2|10',
#        'HousePlant|2|18',
#        'Plate|2|12',
#        'Knife|2|7']}},
#     'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'front', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'Knife|2|7': {'object_name': 'knife',
#      'egocentric_label': {'horiz': 'front', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'Plate|2|12': {'object_name': 'plate',
#      'egocentric_label': {'horiz': 'front', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'ObjaPouch|2|1': {'object_name': 'pouch',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'HousePlant|2|18': {'object_name': 'plant',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}}}},
#   {'step': 2,
#    'action': 'rotate_right',
#    'degrees': 30,
#    'objects': {'ObjaPepper|2|3': {'object_name': 'pepper',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'wall|exterior|4.83|3.22|6.44|3.22': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'ObjaCounter|2|1': {'object_name': 'counter',
#      'egocentric_label': {'horiz': 'left', 'vert': 'below', 'dist': 'near'},
#      'relations': {'contains': ['ObjaPouch|2|1',
#        'Cup|2|9',
#        'ObjaPepper|2|3',
#        'Cup|2|10',
#        'HousePlant|2|18',
#        'Plate|2|12',
#        'Knife|2|7']}},
#     'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'Knife|2|7': {'object_name': 'knife',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'Plate|2|12': {'object_name': 'plate',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'HousePlant|2|18': {'object_name': 'plant',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}}}},
#   {'step': 3,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'ObjaPepper|2|3': {'object_name': 'pepper',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'ObjaCounter|2|1': {'object_name': 'counter',
#      'egocentric_label': {'horiz': 'left', 'vert': 'below', 'dist': 'near'},
#      'relations': {'contains': ['ObjaPouch|2|1',
#        'Cup|2|9',
#        'ObjaPepper|2|3',
#        'Cup|2|10',
#        'HousePlant|2|18',
#        'Plate|2|12',
#        'Knife|2|7']}},
#     'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'window|2|0': {'object_name': 'window',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'Knife|2|7': {'object_name': 'knife',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'Plate|2|12': {'object_name': 'plate',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}}}},
#   {'step': 4,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'ObjaCounter|2|1': {'object_name': 'counter',
#      'egocentric_label': {'horiz': 'left', 'vert': 'below', 'dist': 'near'},
#      'relations': {'contains': ['ObjaPouch|2|1',
#        'Cup|2|9',
#        'ObjaPepper|2|3',
#        'Cup|2|10',
#        'HousePlant|2|18',
#        'Plate|2|12',
#        'Knife|2|7']}},
#     'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'Knife|2|7': {'object_name': 'knife',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'Plate|2|12': {'object_name': 'plate',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'window|2|0': {'object_name': 'window',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}}}},
#   {'step': 5,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'ObjaCounter|2|1': {'object_name': 'counter',
#      'egocentric_label': {'horiz': 'left', 'vert': 'below', 'dist': 'near'},
#      'relations': {'contains': ['ObjaPouch|2|1',
#        'Cup|2|9',
#        'ObjaPepper|2|3',
#        'Cup|2|10',
#        'HousePlant|2|18',
#        'Plate|2|12',
#        'Knife|2|7']}},
#     'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'window|2|0': {'object_name': 'window',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'Knife|2|7': {'object_name': 'knife',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}}}},
#   {'step': 6,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}}}},
#   {'step': 7,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'ObjaRefrigerator|2|3': {'object_name': 'refrigerator',
#      'egocentric_label': {'horiz': 'right', 'vert': 'below', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}},
#     'window|2|0': {'object_name': 'window',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}}}},
#   {'step': 8,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'ObjaRefrigerator|2|3': {'object_name': 'refrigerator',
#      'egocentric_label': {'horiz': 'right', 'vert': 'below', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'window|2|0': {'object_name': 'window',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}}}},
#   {'step': 9,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'wall|exterior|3.22|3.22|3.22|4.83': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'ObjaRefrigerator|2|3': {'object_name': 'refrigerator',
#      'egocentric_label': {'horiz': 'right', 'vert': 'below', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'window|2|0': {'object_name': 'window',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'near'},
#      'relations': {'contains': []}}}},
#   {'step': 10,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'wall|exterior|3.22|3.22|3.22|4.83': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'wall|2|0.00|3.22|3.22|3.22': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'front', 'vert': '', 'dist': 'far'},
#      'relations': {'contains': []}},
#     'wall|exterior|3.22|1.61|6.44|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'wall|2|3.22|0.00|3.22|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}}}},
#   {'step': 11,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'wall|exterior|3.22|3.22|3.22|4.83': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'wall|2|0.00|3.22|3.22|3.22': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'far'},
#      'relations': {'contains': []}},
#     'wall|2|3.22|0.00|3.22|1.61': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'left', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}}}},
#   {'step': 12,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'wall|2|0.00|3.22|3.22|3.22': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'far'},
#      'relations': {'contains': []}}}},
#   {'step': 13,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'wall|2|0.00|3.22|3.22|3.22': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}}}},
#   {'step': 14,
#    'action': 'move_ahead',
#    'degrees': 30,
#    'objects': {'wall|2|0.00|3.22|3.22|3.22': {'object_name': 'wall',
#      'egocentric_label': {'horiz': 'right', 'vert': '', 'dist': 'medium'},
#      'relations': {'contains': []}},
#     'door|1|2': {'object_name': 'doorway',
#      'egocentric_label': {'horiz': 'front', 'vert': 'below', 'dist': 'far'},
#      'relations': {'contains': []}}}}]}

# %%
spat_ann
# Out:
# {'episode': 'ep_1',
#  'sequence': [{'step': 0,
#    'objects': {'ObjaPepper|2|3': "From the agent's viewpoint, the pepper is to the right of the agent and near",
#     'Cup|2|10': "From the agent's viewpoint, the cup is in front of the agent and near",
#     'ObjaCounter|2|1': "From the agent's viewpoint, the counter is in front of the agent, near and below eye level",
#     'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is to the right of the agent and at a medium distance",
#     'Cup|2|9': "From the agent's viewpoint, the cup is to the left of the agent and near",
#     'Knife|2|7': "From the agent's viewpoint, the knife is to the right of the agent and near",
#     'Plate|2|12': "From the agent's viewpoint, the plate is to the right of the agent and near",
#     'ObjaPouch|2|1': "From the agent's viewpoint, the pouch is to the left of the agent and near",
#     'HousePlant|2|18': "From the agent's viewpoint, the plant is in front of the agent and near"}},
#   {'step': 1,
#    'objects': {'ObjaPepper|2|3': "From the agent's viewpoint, the pepper is in front of the agent and near",
#     'Cup|2|10': "From the agent's viewpoint, the cup is to the left of the agent and near",
#     'ObjaCounter|2|1': "From the agent's viewpoint, the counter is to the left of the agent, near and below eye level",
#     'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is in front of the agent and at a medium distance",
#     'Knife|2|7': "From the agent's viewpoint, the knife is in front of the agent and near",
#     'Plate|2|12': "From the agent's viewpoint, the plate is in front of the agent and near",
#     'ObjaPouch|2|1': "From the agent's viewpoint, the pouch is to the left of the agent and near",
#     'HousePlant|2|18': "From the agent's viewpoint, the plant is to the left of the agent and near"}},
#   {'step': 2,
#    'objects': {'ObjaPepper|2|3': "From the agent's viewpoint, the pepper is to the left of the agent and near",
#     'wall|exterior|4.83|3.22|6.44|3.22': "From the agent's viewpoint, the wall is to the right of the agent and near",
#     'ObjaCounter|2|1': "From the agent's viewpoint, the counter is to the left of the agent, near and below eye level",
#     'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is to the left of the agent and at a medium distance",
#     'Knife|2|7': "From the agent's viewpoint, the knife is to the left of the agent and near",
#     'Plate|2|12': "From the agent's viewpoint, the plate is to the left of the agent and near",
#     'HousePlant|2|18': "From the agent's viewpoint, the plant is to the left of the agent and near"}},
#   {'step': 3,
#    'objects': {'ObjaPepper|2|3': "From the agent's viewpoint, the pepper is to the left of the agent and near",
#     'ObjaCounter|2|1': "From the agent's viewpoint, the counter is to the left of the agent, near and below eye level",
#     'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is to the left of the agent and at a medium distance",
#     'window|2|0': "From the agent's viewpoint, the window is to the left of the agent and near",
#     'Knife|2|7': "From the agent's viewpoint, the knife is to the left of the agent and near",
#     'Plate|2|12': "From the agent's viewpoint, the plate is to the left of the agent and near"}},
#   {'step': 4,
#    'objects': {'ObjaCounter|2|1': "From the agent's viewpoint, the counter is to the left of the agent, near and below eye level",
#     'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is to the left of the agent and at a medium distance",
#     'Knife|2|7': "From the agent's viewpoint, the knife is to the left of the agent and near",
#     'Plate|2|12': "From the agent's viewpoint, the plate is to the left of the agent and near",
#     'window|2|0': "From the agent's viewpoint, the window is to the left of the agent and near"}},
#   {'step': 5,
#    'objects': {'ObjaCounter|2|1': "From the agent's viewpoint, the counter is to the left of the agent, near and below eye level",
#     'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is to the left of the agent and at a medium distance",
#     'window|2|0': "From the agent's viewpoint, the window is to the left of the agent and near",
#     'Knife|2|7': "From the agent's viewpoint, the knife is to the left of the agent and near"}},
#   {'step': 6,
#    'objects': {'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is to the left of the agent and at a medium distance"}},
#   {'step': 7,
#    'objects': {'ObjaRefrigerator|2|3': "From the agent's viewpoint, the refrigerator is to the right of the agent, at a medium distance and below eye level",
#     'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is to the left of the agent and near",
#     'window|2|0': "From the agent's viewpoint, the window is to the left of the agent and near"}},
#   {'step': 8,
#    'objects': {'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is to the left of the agent and at a medium distance",
#     'ObjaRefrigerator|2|3': "From the agent's viewpoint, the refrigerator is to the right of the agent, at a medium distance and below eye level",
#     'window|2|0': "From the agent's viewpoint, the window is to the left of the agent and near"}},
#   {'step': 9,
#    'objects': {'wall|exterior|3.22|3.22|3.22|4.83': "From the agent's viewpoint, the wall is to the right of the agent and at a medium distance",
#     'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is to the left of the agent and at a medium distance",
#     'ObjaRefrigerator|2|3': "From the agent's viewpoint, the refrigerator is to the right of the agent, at a medium distance and below eye level",
#     'window|2|0': "From the agent's viewpoint, the window is to the left of the agent and near"}},
#   {'step': 10,
#    'objects': {'wall|exterior|3.22|3.22|3.22|4.83': "From the agent's viewpoint, the wall is to the right of the agent and at a medium distance",
#     'wall|2|0.00|3.22|3.22|3.22': "From the agent's viewpoint, the wall is in front of the agent and far away",
#     'wall|exterior|3.22|1.61|6.44|1.61': "From the agent's viewpoint, the wall is to the left of the agent and at a medium distance",
#     'wall|2|3.22|0.00|3.22|1.61': "From the agent's viewpoint, the wall is to the left of the agent and at a medium distance"}},
#   {'step': 11,
#    'objects': {'wall|exterior|3.22|3.22|3.22|4.83': "From the agent's viewpoint, the wall is to the right of the agent and at a medium distance",
#     'wall|2|0.00|3.22|3.22|3.22': "From the agent's viewpoint, the wall is to the right of the agent and far away",
#     'wall|2|3.22|0.00|3.22|1.61': "From the agent's viewpoint, the wall is to the left of the agent and at a medium distance"}},
#   {'step': 12,
#    'objects': {'wall|2|0.00|3.22|3.22|3.22': "From the agent's viewpoint, the wall is to the right of the agent and far away"}},
#   {'step': 13,
#    'objects': {'wall|2|0.00|3.22|3.22|3.22': "From the agent's viewpoint, the wall is to the right of the agent and at a medium distance"}},
#   {'step': 14,
#    'objects': {'wall|2|0.00|3.22|3.22|3.22': "From the agent's viewpoint, the wall is to the right of the agent and at a medium distance",
#     'door|1|2': "From the agent's viewpoint, the doorway is in front of the agent, far away and below eye level"}}]}

# %%
traj
# Out:
# {'episode': 'ep_1',
#  'ObjaPepper|2|3': [{'step': 0, 'horiz': 'right', 'vert': '', 'dist': 'near'},
#   {'step': 1, 'horiz': 'front', 'vert': '', 'dist': 'near'},
#   {'step': 2, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 3, 'horiz': 'left', 'vert': '', 'dist': 'near'}],
#  'Cup|2|10': [{'step': 0, 'horiz': 'front', 'vert': '', 'dist': 'near'},
#   {'step': 1, 'horiz': 'left', 'vert': '', 'dist': 'near'}],
#  'ObjaCounter|2|1': [{'step': 0,
#    'horiz': 'front',
#    'vert': 'below',
#    'dist': 'near'},
#   {'step': 1, 'horiz': 'left', 'vert': 'below', 'dist': 'near'},
#   {'step': 2, 'horiz': 'left', 'vert': 'below', 'dist': 'near'},
#   {'step': 3, 'horiz': 'left', 'vert': 'below', 'dist': 'near'},
#   {'step': 4, 'horiz': 'left', 'vert': 'below', 'dist': 'near'},
#   {'step': 5, 'horiz': 'left', 'vert': 'below', 'dist': 'near'}],
#  'wall|exterior|3.22|1.61|6.44|1.61': [{'step': 0,
#    'horiz': 'right',
#    'vert': '',
#    'dist': 'medium'},
#   {'step': 1, 'horiz': 'front', 'vert': '', 'dist': 'medium'},
#   {'step': 2, 'horiz': 'left', 'vert': '', 'dist': 'medium'},
#   {'step': 3, 'horiz': 'left', 'vert': '', 'dist': 'medium'},
#   {'step': 4, 'horiz': 'left', 'vert': '', 'dist': 'medium'},
#   {'step': 5, 'horiz': 'left', 'vert': '', 'dist': 'medium'},
#   {'step': 6, 'horiz': 'left', 'vert': '', 'dist': 'medium'},
#   {'step': 7, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 8, 'horiz': 'left', 'vert': '', 'dist': 'medium'},
#   {'step': 9, 'horiz': 'left', 'vert': '', 'dist': 'medium'},
#   {'step': 10, 'horiz': 'left', 'vert': '', 'dist': 'medium'}],
#  'Cup|2|9': [{'step': 0, 'horiz': 'left', 'vert': '', 'dist': 'near'}],
#  'Knife|2|7': [{'step': 0, 'horiz': 'right', 'vert': '', 'dist': 'near'},
#   {'step': 1, 'horiz': 'front', 'vert': '', 'dist': 'near'},
#   {'step': 2, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 3, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 4, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 5, 'horiz': 'left', 'vert': '', 'dist': 'near'}],
#  'Plate|2|12': [{'step': 0, 'horiz': 'right', 'vert': '', 'dist': 'near'},
#   {'step': 1, 'horiz': 'front', 'vert': '', 'dist': 'near'},
#   {'step': 2, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 3, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 4, 'horiz': 'left', 'vert': '', 'dist': 'near'}],
#  'ObjaPouch|2|1': [{'step': 0, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 1, 'horiz': 'left', 'vert': '', 'dist': 'near'}],
#  'HousePlant|2|18': [{'step': 0, 'horiz': 'front', 'vert': '', 'dist': 'near'},
#   {'step': 1, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 2, 'horiz': 'left', 'vert': '', 'dist': 'near'}],
#  'wall|exterior|4.83|3.22|6.44|3.22': [{'step': 2,
#    'horiz': 'right',
#    'vert': '',
#    'dist': 'near'}],
#  'window|2|0': [{'step': 3, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 4, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 5, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 7, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 8, 'horiz': 'left', 'vert': '', 'dist': 'near'},
#   {'step': 9, 'horiz': 'left', 'vert': '', 'dist': 'near'}],
#  'ObjaRefrigerator|2|3': [{'step': 7,
#    'horiz': 'right',
#    'vert': 'below',
#    'dist': 'medium'},
#   {'step': 8, 'horiz': 'right', 'vert': 'below', 'dist': 'medium'},
#   {'step': 9, 'horiz': 'right', 'vert': 'below', 'dist': 'medium'}],
#  'wall|exterior|3.22|3.22|3.22|4.83': [{'step': 9,
#    'horiz': 'right',
#    'vert': '',
#    'dist': 'medium'},
#   {'step': 10, 'horiz': 'right', 'vert': '', 'dist': 'medium'},
#   {'step': 11, 'horiz': 'right', 'vert': '', 'dist': 'medium'}],
#  'wall|2|0.00|3.22|3.22|3.22': [{'step': 10,
#    'horiz': 'front',
#    'vert': '',
#    'dist': 'far'},
#   {'step': 11, 'horiz': 'right', 'vert': '', 'dist': 'far'},
#   {'step': 12, 'horiz': 'right', 'vert': '', 'dist': 'far'},
#   {'step': 13, 'horiz': 'right', 'vert': '', 'dist': 'medium'},
#   {'step': 14, 'horiz': 'right', 'vert': '', 'dist': 'medium'}],
#  'wall|2|3.22|0.00|3.22|1.61': [{'step': 10,
#    'horiz': 'left',
#    'vert': '',
#    'dist': 'medium'},
#   {'step': 11, 'horiz': 'left', 'vert': '', 'dist': 'medium'}],
#  'door|1|2': [{'step': 14, 'horiz': 'front', 'vert': 'below', 'dist': 'far'}]}

# %%
import json

# %%
def export_to_json(filename, data):
    with open(filename, "w") as f:
        json.dump(data, f, indent=4)

# %%
export_to_json("navigation_1.json", sp_data)
export_to_json("spatial_description_1.json", spat_ann)
export_to_json("trajectories_1.json", traj)
